# %% [markdown]
# <a href="https://colab.research.google.com/github/ola-dob/My_repository/blob/main/Task10_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
def website_analyse(file_path):
    df = pd.read_csv(file_path)

    avg_pages = df['Просмотренные страницы'].mean()
    print(f"1) Среднее количество просмотренных таблиц: {avg_pages}")

    std_time = df['Время на сайте (сек)'].std()
    print(f"2) Стандартное отклонение: {std_time}")

    cv = std_time / df['Время на сайте (сек)'].mean()

    if cv > 0.25:
        variability = "Высокая вариабельность"
    elif cv > 0.1:
        variability = "Умеренная вариабельность"
    else:
        variability = "Слабая вариабельность"

    print(f"3) {variability}: {cv}")

    mobile_pages = df[df['Тип устройства'] == 'Мобильное']['Просмотренные страницы']
    desktop_pages = df[df['Тип устройства'] == 'Десктоп']['Просмотренные страницы']

    t_stat, p_value = stats.ttest_ind(mobile_pages, desktop_pages)

    if p_value > 0.05:
        result = "Есть статистически значимая разница в количестве страниц"
    else:
        result = "Нет статистически значимой разницы"

    print(f"4) {result}: {p_value}")

# %%
website_analyse('website_visits_december_2024.csv')
# Out:
# 1) Среднее количество просмотренных таблиц: 17.486992715920916
# 2) Стандартное отклонение: 1442.7984472210853
# 3) Высокая вариабельность: 0.69243252310509
# 4) Нет статистически значимой разницы: 0.00013741248854821084
